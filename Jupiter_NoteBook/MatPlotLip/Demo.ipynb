# %%
import matplotlib.pyplot as plt # or also we can use for import matplotlib
from matplotlib import pyplot as plt

x = [1,2,3,4,5]
y = [2,4,6,8,10]

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
c = ["r","g",'b',"y","black"]

plt.bar(x,y,color = c)
plt.show()
