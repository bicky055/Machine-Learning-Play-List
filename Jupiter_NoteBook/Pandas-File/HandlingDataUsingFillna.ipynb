# %% [markdown]
# # Fillna Fuction to Fill data

# %%
import pandas as pd
data = pd.read_csv("C:\\Users\\VIKRAM\\Desktop\\Jupiter_NoteBook\\people-100.csv")
data
# Out:
#     Index          User Id   User Id.1 Last Name     Sex  \
# 0     1.0  88F7B33d2bcf9f5      Shelby   Terrell    Male
# 1     2.0  f90cD3E76f1A9b9     Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c         NaN       NaN    Male
# 3     NaN              NaN         NaN       NaN     NaN
# 4     5.0  1bA7A3dc874da3c        Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B        Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7   Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC     Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB        Dave   Farrell     NaN
# 9    10.0  8e4FB470FE19bF0      Isaiah     Downs    Male
# 10   11.0  BF0BbA03C29Bb3b      Sheila      Ross  Female
# 11   12.0  F738c69fB34E62E       Stacy    Newton    Male
# 12   13.0  C03fDADdAadAdCe       Mandy     Blake    Male
# 13   14.0  b759b74BD1dE80d     Bridget      Nash  Female
# 14   15.0  1F0B7D65A00DAF9     Crystal    Farmer    Male
# ...

# %%
data.fillna("Python")
# Out:
#      Index          User Id   User Id.1 Last Name     Sex  \
# 0      1.0  88F7B33d2bcf9f5      Shelby   Terrell    Male
# 1      2.0  f90cD3E76f1A9b9     Phillip   Summers  Female
# 2      3.0  DbeAb8CcdfeFC2c      Python    Python    Male
# 3   Python           Python      Python    Python  Python
# 4      5.0  1bA7A3dc874da3c        Lori      Todd    Male
# 5      6.0  bfDD7CDEF5D865B        Erin       Day    Male
# 6      7.0  bE9EEf34cB72AF7   Katherine      Buck  Female
# 7      8.0  2EFC6A4e77FaEaC     Ricardo    Hinton    Male
# 8      9.0  baDcC4DeefD8dEB        Dave   Farrell  Python
# 9     10.0  8e4FB470FE19bF0      Isaiah     Downs    Male
# 10    11.0  BF0BbA03C29Bb3b      Sheila      Ross  Female
# 11    12.0  F738c69fB34E62E       Stacy    Newton    Male
# 12    13.0  C03fDADdAadAdCe       Mandy     Blake    Male
# 13    14.0  b759b74BD1dE80d     Bridget      Nash  Female
# 14    15.0  1F0B7D65A00DAF9     Crystal    Farmer    Male
# ...

# %%
data.fillna({"Sex": "Male","User Id":"Bicky055"})
# Out:
#     Index          User Id   User Id.1 Last Name     Sex  \
# 0     1.0  88F7B33d2bcf9f5      Shelby   Terrell    Male
# 1     2.0  f90cD3E76f1A9b9     Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c         NaN       NaN    Male
# 3     NaN         Bicky055         NaN       NaN    Male
# 4     5.0  1bA7A3dc874da3c        Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B        Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7   Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC     Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB        Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0      Isaiah     Downs    Male
# 10   11.0  BF0BbA03C29Bb3b      Sheila      Ross  Female
# 11   12.0  F738c69fB34E62E       Stacy    Newton    Male
# 12   13.0  C03fDADdAadAdCe       Mandy     Blake    Male
# 13   14.0  b759b74BD1dE80d     Bridget      Nash  Female
# 14   15.0  1F0B7D65A00DAF9     Crystal    Farmer    Male
# ...

# %%
data.fillna(method = "ffill") # fill upder values  copy where NaN and for lower values use "bfill"
# Out:
# C:\Users\VIKRAM\AppData\Local\Temp\ipykernel_22268\3381289140.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method = "ffill")
#     Index          User Id   User Id.1 Last Name     Sex  \
# 0     1.0  88F7B33d2bcf9f5      Shelby   Terrell    Male
# 1     2.0  f90cD3E76f1A9b9     Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c     Phillip   Summers    Male
# 3     3.0  DbeAb8CcdfeFC2c     Phillip   Summers    Male
# 4     5.0  1bA7A3dc874da3c        Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B        Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7   Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC     Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB        Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0      Isaiah     Downs    Male
# 10   11.0  BF0BbA03C29Bb3b      Sheila      Ross  Female
# ...

# %%
data.fillna(method = "bfill", axis = 0)
# Out:
# C:\Users\VIKRAM\AppData\Local\Temp\ipykernel_22268\4229226815.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method = "bfill", axis = 0)
#     Index          User Id   User Id.1 Last Name     Sex  \
# 0     1.0  88F7B33d2bcf9f5      Shelby   Terrell    Male
# 1     2.0  f90cD3E76f1A9b9     Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        Lori      Todd    Male
# 3     5.0  1bA7A3dc874da3c        Lori      Todd    Male
# 4     5.0  1bA7A3dc874da3c        Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B        Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7   Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC     Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB        Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0      Isaiah     Downs    Male
# 10   11.0  BF0BbA03C29Bb3b      Sheila      Ross  Female
# ...
