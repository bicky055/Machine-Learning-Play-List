# %% [markdown]
# # Replace Fuction

# %%
import pandas as pd

data = pd.read_csv("C:\\Users\\VIKRAM\\Desktop\\Jupiter_NoteBook\\organizations.csv")
data
# Out:
#     Index  Organization Id                      Name  \
# 0       1  FAB0d41d5b5d22c               Ferrell LLC
# 1       2  6A7EdDEA9FaDC52   Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                Hester Ltd
# 3       4  2bFC1Be8a4ce42f            Holder-Sellers
# 4       5  9eE8A6a4Eb96C24               Mayer Group
# 5       6  cC757116fe1C085            Henry-Thompson
# 6       7  219233e8aFF1BC3            Hansen-Everett
# 7       8  ccc93DCF81a31CD             Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                  Carr Inc
# 9      10  738b5aDe6B1C6A5                Gaines Inc
# 10     11  AE61b8Ffebbc476                Kidd Group
# 11     12  eb3B7D06cCdD609              Crane-Clarke
# 12     13  8D0c29189C9798B  Keller, Campos and Black
# 13     14  D2c91cc03CA394c               Glover-Pope
#
#                               Country  Founded  Number of employees
# 0                    Papua New Guinea     1990                 3498
# ...

# %%
data.replace(to_replace = 1, value = 22)
# Out:
#     Index  Organization Id                      Name  \
# 0      22  FAB0d41d5b5d22c               Ferrell LLC
# 1       2  6A7EdDEA9FaDC52   Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                Hester Ltd
# 3       4  2bFC1Be8a4ce42f            Holder-Sellers
# 4       5  9eE8A6a4Eb96C24               Mayer Group
# 5       6  cC757116fe1C085            Henry-Thompson
# 6       7  219233e8aFF1BC3            Hansen-Everett
# 7       8  ccc93DCF81a31CD             Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                  Carr Inc
# 9      10  738b5aDe6B1C6A5                Gaines Inc
# 10     11  AE61b8Ffebbc476                Kidd Group
# 11     12  eb3B7D06cCdD609              Crane-Clarke
# 12     13  8D0c29189C9798B  Keller, Campos and Black
# 13     14  D2c91cc03CA394c               Glover-Pope
#
#                               Country  Founded  Number of employees
# 0                    Papua New Guinea     1990                 3498
# ...

# %%
data.replace({2:40,1:'bK'}) # using Dictionary
# Out:
#    Index  Organization Id                      Name  \
# 0     bK  FAB0d41d5b5d22c               Ferrell LLC
# 1     40  6A7EdDEA9FaDC52   Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1                Hester Ltd
# 3      4  2bFC1Be8a4ce42f            Holder-Sellers
# 4      5  9eE8A6a4Eb96C24               Mayer Group
# 5      6  cC757116fe1C085            Henry-Thompson
# 6      7  219233e8aFF1BC3            Hansen-Everett
# 7      8  ccc93DCF81a31CD             Mcintosh-Mora
# 8      9  0B4F93aA06ED03e                  Carr Inc
# 9     10  738b5aDe6B1C6A5                Gaines Inc
# 10    11  AE61b8Ffebbc476                Kidd Group
# 11    12  eb3B7D06cCdD609              Crane-Clarke
# 12    13  8D0c29189C9798B  Keller, Campos and Black
# 13    14  D2c91cc03CA394c               Glover-Pope
#
#                               Country Founded  Number of employees
# 0                    Papua New Guinea    1990                 3498
# ...

# %%
#data.replace("[A-Za-z]","bicky",regex = True)
data.replace(1,"bicky",regex = True)
# Out:
#     Index  Organization Id                      Name  \
# 0   bicky  FAB0d41d5b5d22c               Ferrell LLC
# 1       2  6A7EdDEA9FaDC52   Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                Hester Ltd
# 3       4  2bFC1Be8a4ce42f            Holder-Sellers
# 4       5  9eE8A6a4Eb96C24               Mayer Group
# 5       6  cC757116fe1C085            Henry-Thompson
# 6       7  219233e8aFF1BC3            Hansen-Everett
# 7       8  ccc93DCF81a31CD             Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                  Carr Inc
# 9      10  738b5aDe6B1C6A5                Gaines Inc
# 10     11  AE61b8Ffebbc476                Kidd Group
# 11     12  eb3B7D06cCdD609              Crane-Clarke
# 12     13  8D0c29189C9798B  Keller, Campos and Black
# 13     14  D2c91cc03CA394c               Glover-Pope
#
#                               Country Founded  Number of employees
# 0                    Papua New Guinea    1990                 3498
# ...

# %%
data.replace(1,method = 'ffill')
# Out:
# C:\Users\VIKRAM\AppData\Local\Temp\ipykernel_22676\18749633.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   data.replace(1,method = 'ffill')
#     Index  Organization Id                      Name  \
# 0       1  FAB0d41d5b5d22c               Ferrell LLC
# 1       2  6A7EdDEA9FaDC52   Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                Hester Ltd
# 3       4  2bFC1Be8a4ce42f            Holder-Sellers
# 4       5  9eE8A6a4Eb96C24               Mayer Group
# 5       6  cC757116fe1C085            Henry-Thompson
# 6       7  219233e8aFF1BC3            Hansen-Everett
# 7       8  ccc93DCF81a31CD             Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                  Carr Inc
# 9      10  738b5aDe6B1C6A5                Gaines Inc
# 10     11  AE61b8Ffebbc476                Kidd Group
# 11     12  eb3B7D06cCdD609              Crane-Clarke
# 12     13  8D0c29189C9798B  Keller, Campos and Black
# ...

# %%
data.replace(1,method = 'bfill',limit=3)
# Out:
# C:\Users\VIKRAM\AppData\Local\Temp\ipykernel_22676\3319073871.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   data.replace(1,method = 'bfill',limit=3)
#     Index  Organization Id                      Name  \
# 0       2  FAB0d41d5b5d22c               Ferrell LLC
# 1       2  6A7EdDEA9FaDC52   Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                Hester Ltd
# 3       4  2bFC1Be8a4ce42f            Holder-Sellers
# 4       5  9eE8A6a4Eb96C24               Mayer Group
# 5       6  cC757116fe1C085            Henry-Thompson
# 6       7  219233e8aFF1BC3            Hansen-Everett
# 7       8  ccc93DCF81a31CD             Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                  Carr Inc
# 9      10  738b5aDe6B1C6A5                Gaines Inc
# 10     11  AE61b8Ffebbc476                Kidd Group
# 11     12  eb3B7D06cCdD609              Crane-Clarke
# 12     13  8D0c29189C9798B  Keller, Campos and Black
# ...
